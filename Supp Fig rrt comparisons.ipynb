# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#import rrt datasets
p = 'Codon data/'
rrt_files = os.listdir(p)
rrt_df = pd.DataFrame()
for rrt_file in rrt_files:
    if rrt_file[0] != '.':
        if rrt_df.shape == (0, 0):
            rrt_df = pd.read_csv(p + rrt_file)
            rrt_df.columns = [rrt_df.columns[0], rrt_file[:-4]]
        else:
            add_df = pd.read_csv(p + rrt_file)
            add_df.columns = [add_df.columns[0], rrt_file[:-4]]
            rrt_df = rrt_df.merge(add_df, on='codon')

# %%
plot = sns.pairplot(rrt_df)
for ax in plot.axes.flatten():
    xlab = ax.get_xlabel()
    if len(xlab) ==0: continue
    ax.set_xlim((0,6))

    ylab = ax.get_ylabel()
    if len(ylab)==0: continue
    ax.set_ylim((0,6))
plot.savefig('Supp fig pairwise rrts.png')
# Out:
# /home/tobiasvonderhaar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tobiasvonderhaar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tobiasvonderhaar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tobiasvonderhaar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tobiasvonderhaar/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
